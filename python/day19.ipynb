# %%
# Modules to support development
import os
import re
import collections
import itertools
import functools
import logging
import pprint
import numpy as np
import heapq
import copy
from tqdm import tqdm
import math
import nographs as nog

# %%
class Blueprint():
    def __init__(self):
        self.id = None
        self.costs = {}

    def parse_blueprint(self, blueprint):
        mm = re.match("Blueprint (\d+): (.*)", blueprint)
        if not mm:
            raise ValueError

        self.id = int( mm.group(1) )
        costs = mm.group(2)
        
        for cost_ll in costs.split("."):
            if cost_ll.strip() == "":
                continue

            mm = re.match("Each (\w+) robot costs (\d+) (\w+)(?:\s+and (\d+) (\w+))?", cost_ll.strip())
            if not mm:
                raise ValueError(cost_ll)
            what = mm.group(1)
            cost = int(mm.group(2))
            item = mm.group(3)

            self.costs.setdefault(what, {})[item] = cost
            if mm.group(4) is not None:
                cost = int(mm.group(4))
                item = mm.group(5)
                self.costs.setdefault(what, {})[item] = cost

def test_parse_blueprint(): 
    b = Blueprint()
    b.parse_blueprint("Blueprint 1: Each ore robot costs 4 ore. Each clay robot costs 4 ore. Each obsidian robot costs 2 ore and 11 clay. Each geode robot costs 4 ore and 8 obsidian.")
    assert b.id == 1
    print(b.costs)

def read_input(puzzle_input):
    with open(puzzle_input) as ff:
        dd = ff.readlines()

    blueprints = []
    for ll in dd:
        bb = Blueprint()
        bb.parse_blueprint(ll)
        blueprints.append(bb)

    return blueprints

def test_read_input():
    blueprints = read_input(os.path.join(os.path.join("..", "dat", "day19_test.txt")))
    for bb in blueprints:
        print(bb.id, bb.costs)

test_read_input()
# Out:
# 1 {'ore': {'ore': 4}, 'clay': {'ore': 2}, 'obsidian': {'ore': 3, 'clay': 14}, 'geode': {'ore': 2, 'obsidian': 7}}
# 2 {'ore': {'ore': 2}, 'clay': {'ore': 3}, 'obsidian': {'ore': 3, 'clay': 8}, 'geode': {'ore': 3, 'obsidian': 12}}

# %%
State = collections.namedtuple("State", "ore clay obsidian geode ore_r clay_r obsidian_r geode_r")

def next_state(state, blueprint):
    can_build_all = True
    for build in ("ore", "clay", "obsidian"):
        remaining_ore = state.ore_r - blueprint.costs.get(build, {}).get("ore", 0)
        remaining_clay = state.clay_r - blueprint.costs.get(build, {}).get("clay", 0)
        remaining_obsidian = state.obsidian_r - blueprint.costs.get(build, {}).get("obsidian", 0)
        can_build_all = remaining_ore >= 0 and remaining_clay >= 0 and remaining_obsidian >= 0
        if can_build_all == False:
            break

    if can_build_all:
        build_list = (None, "geode")
    else:
        build_list = (None, "ore", "clay", "obsidian", "geode")

    for build in build_list:
        remaining_ore = state.ore - blueprint.costs.get(build, {}).get("ore", 0)
        remaining_clay = state.clay - blueprint.costs.get(build, {}).get("clay", 0)
        remaining_obsidian = state.obsidian - blueprint.costs.get(build, {}).get("obsidian", 0)
        can_build = remaining_ore >= 0 and remaining_clay >= 0 and remaining_obsidian >= 0

        if build is None:   
            yield build, State(
                #state.depth + 1,
                remaining_ore + state.ore_r,
                remaining_clay + state.clay_r,
                remaining_obsidian + state.obsidian_r,
                state.geode + state.geode_r,
                state.ore_r,
                state.clay_r,
                state.obsidian_r,
                state.geode_r,
            )
        elif can_build == False:
            continue
        elif build == "ore":
            yield build, State(
                #state.depth + 1,
                remaining_ore + state.ore_r,
                remaining_clay + state.clay_r,
                remaining_obsidian + state.obsidian_r,
                state.geode + state.geode_r,
                state.ore_r + 1,
                state.clay_r,
                state.obsidian_r,
                state.geode_r,
            )
        elif build == "clay":
            yield build, State(
                #state.depth + 1,
                remaining_ore + state.ore_r,
                remaining_clay + state.clay_r,
                remaining_obsidian + state.obsidian_r,
                state.geode + state.geode_r,
                state.ore_r,
                state.clay_r + 1,
                state.obsidian_r,
                state.geode_r,
            )
        elif build == "obsidian":
            yield build, State(
                #state.depth + 1,
                remaining_ore + state.ore_r,
                remaining_clay + state.clay_r,
                remaining_obsidian + state.obsidian_r,
                state.geode + state.geode_r,
                state.ore_r,
                state.clay_r,
                state.obsidian_r + 1,
                state.geode_r,
            )
        elif build == "geode":
            yield build, State(
                #state.depth + 1,
                remaining_ore + state.ore_r,
                remaining_clay + state.clay_r,
                remaining_obsidian + state.obsidian_r,
                state.geode + state.geode_r,
                state.ore_r,
                state.clay_r,
                state.obsidian_r,
                state.geode_r + 1,
            )            

def test_next_state():
    blueprints = read_input(os.path.join(os.path.join("..", "dat", "day19_test.txt")))
    state = State(0, 0, 0, 0, 0, 1, 0, 0, 0)
    states = list(next_state(state, blueprints[0]))
    assert(len(states) == 1)
    assert states[0] == State(1, 1, 0, 0, 0, 1, 0, 0, 0)
    
    state = State(1, 1, 0, 0, 0, 1, 0, 0, 0)
    states = list(next_state(state, blueprints[0]))
    assert(len(states) == 1)
    assert states[0] == State(2, 2, 0, 0, 0, 1, 0, 0, 0)

    state = State(2, 2, 0, 0, 0, 1, 0, 0, 0)
    states = list(next_state(state, blueprints[0]))
    assert(len(states) == 2)
    assert states[0] == State(3, 3, 0, 0, 0, 1, 0, 0, 0)
    assert states[1] == State(3, 1, 0, 0, 0, 1, 1, 0, 0)

    state = State(3, 4, 0, 0, 0, 1, 1, 0, 0)
    states = list(next_state(state, blueprints[0]))
    assert(len(states) == 3)
    assert states[0] == State(4, 5, 1, 0, 0, 1, 1, 0, 0) # Build None
    assert states[1] == State(4, 1, 1, 0, 0, 2, 1, 0, 0) # Build ore
    assert states[2] == State(4, 3, 1, 0, 0, 1, 2, 0, 0) # Build clay

    state = State(10, 4, 15, 0, 0, 1, 3, 0, 0)
    states = list(next_state(state, blueprints[0]))
    assert(len(states) == 4)
    assert states[0] == State(11, 5, 18, 0, 0, 1, 3, 0, 0) # Build None
    assert states[1] == State(11, 1, 18, 0, 0, 2, 3, 0, 0) # Build ore
    assert states[2] == State(11, 3, 18, 0, 0, 1, 4, 0, 0) # Build clay
    assert states[3] == State(11, 2, 4, 0, 0, 1, 3, 1, 0) # Build obsidian

    state = State(17, 3, 13, 8, 0, 1, 4, 2, 0)
    states = list(next_state(state, blueprints[0]))
    assert(len(states) == 3)
    assert states[0] == State(18, 4, 17, 10, 0, 1, 4, 2, 0) # Build None
    assert states[1] == State(18, 2, 17, 10, 0, 1, 5, 2, 0) # Build clay
    assert states[2] == State(18, 2, 17, 3,  0, 1, 4, 2, 1) # Build geode

    state = State(24,   6, 41, 8, 9,   1, 4, 2, 2)
    states = list(next_state(state, blueprints[0]))
    assert(len(states) == 5)
    assert states[0] == State(25,   7, 45, 10, 11,   1, 4, 2, 2) # Build None
    assert states[1] == State(25,   3, 45, 10, 11,   2, 4, 2, 2) # Build ore
    assert states[2] == State(25,   5, 45, 10, 11,   1, 5, 2, 2) # Build clay
    assert states[3] == State(25,   4, 31, 10, 11,   1, 4, 3, 2) # Build obsidian
    assert states[4] == State(25,   5, 45, 3,  11,   1, 4, 2, 3) # Build geode

#test_next_state()

# %%
def score(state, rounds_left, blueprint):
    # The current score is number of geodes, plus assuming we will generate a geode for each robot
    current_score = state.geode + state.geode_r * rounds_left

    #can_build_geode = (blueprint.costs['geode']['ore'] >= state.ore) or (blueprint.costs['geode']['obsidian'] >= state.obsidian)
    #best_score = 0
    #if state.geode_r > 0 or can_build_geode:
        # Best score is how many geodes we get if we produce a new geode robot each remaining round:
        # sum (n-1)+(n-2)+(n-3)
    n = rounds_left - 1
    best_score = current_score + ((n*(n+1)) // 2)

    return current_score, best_score

# %%
def analyze(blueprint, max_depth):
    global max_score, prune_cnt
    max_score = 0
    prune_cnt = 0

    def next_edges(state, t):
        global max_score, prune_cnt
        minutes_left = max_depth - t.depth

        if minutes_left == 0:
            return

        _, best_score = score(state, minutes_left, blueprint)
        if best_score < max_score:
            prune_cnt += 1
            return 

        next_states = list(next_state(state, blueprint))
        for build, child in next_states:
            child_score, _ = score(child, minutes_left-1, blueprint)
            if child_score > max_score:
                max_score = max(max_score, child_score)
                print("New Max Score", max_score, child, t.depth)
            yield child, 0 if build == "geode" else minutes_left

    traversal = nog.TraversalShortestPaths(next_edges)
    max_geodes = State(0, 0, 0, 0, 1, 0, 0, 0)

    state = State(0, 0, 0, 0, 1, 0, 0, 0)

    last_depth = 0
    for vertex in traversal.start_from(state):       
        #print(vertex, sum([ valves[xx][0] for xx in vertex[2] ]), traversal.depth)
        if vertex.geode > max_geodes.geode:
            max_geodes = vertex
            v_score, v_best_score = score(vertex, max_depth-traversal.depth, blueprint)
            print("MAX", max_geodes, v_score, v_best_score, traversal.depth, prune_cnt)
        #if last_depth != traversal.depth:
        #    print("DEPTH", traversal.depth, prune_cnt, max_score)
        #    last_depth = traversal.depth
    #for ii, path in enumerate(traversal.paths[max_flow]): 
    #    print(ii+1, path)

    return max_geodes.geode

def part2(puzzle_input):
    blueprints = read_input(puzzle_input)
    anss = [ 1 ] * 3
    for ii, blueprint in enumerate(blueprints[0:3]):
        print("="*80)
        ans = analyze(blueprint, 32)
        anss[ii] = ans

    print(anss)
    return anss[0] * anss[1] * anss[2]

ans = part2(os.path.join(os.path.join("..", "dat", "day19_test.txt")))
print(ans)
assert ans == 3472

ans = part2(os.path.join(os.path.join("..", "dat", "day19.txt")))
print(ans)
# Out:
# ================================================================================
# New Max Score 14 State(ore=2, clay=20, obsidian=2, geode=0, ore_r=1, clay_r=4, obsidian_r=2, geode_r=1) 17
# MAX State(ore=1, clay=22, obsidian=4, geode=1, ore_r=1, clay_r=5, obsidian_r=2, geode_r=1) 14 92 19 0
# MAX State(ore=1, clay=14, obsidian=6, geode=2, ore_r=1, clay_r=4, obsidian_r=3, geode_r=1) 14 80 20 0
# New Max Score 25 State(ore=3, clay=29, obsidian=2, geode=3, ore_r=1, clay_r=4, obsidian_r=2, geode_r=2) 20
# MAX State(ore=3, clay=29, obsidian=2, geode=3, ore_r=1, clay_r=4, obsidian_r=2, geode_r=2) 25 80 21 0
# MAX State(ore=2, clay=35, obsidian=4, geode=5, ore_r=1, clay_r=5, obsidian_r=2, geode_r=2) 25 70 22 0
# New Max Score 32 State(ore=2, clay=21, obsidian=6, geode=5, ore_r=2, clay_r=7, obsidian_r=5, geode_r=3) 22
# New Max Score 39 State(ore=2, clay=28, obsidian=5, geode=7, ore_r=2, clay_r=7, obsidian_r=5, geode_r=4) 23
# MAX State(ore=2, clay=28, obsidian=5, geode=7, ore_r=2, clay_r=7, obsidian_r=5, geode_r=4) 39 67 24 0
# MAX State(ore=1, clay=27, obsidian=3, geode=9, ore_r=1, clay_r=4, obsidian_r=3, geode_r=3) 33 61 24 0
# MAX State(ore=2, clay=35, obsidian=10, geode=11, ore_r=2, clay_r=8, obsidian_r=5, geode_r=4) 39 60 25 0
# New Max Score 45 State(ore=2, clay=43, obsidian=8, geode=15, ore_r=2, clay_r=8, obsidian_r=5, geode_r=5) 25
# MAX State(ore=2, clay=43, obsidian=8, geode=15, ore_r=2, clay_r=8, obsidian_r=5, geode_r=5) 45 60 26 0
# New Max Score 50 State(ore=2, clay=51, obsidian=6, geode=20, ore_r=2, clay_r=8, obsidian_r=5, geode_r=6) 26
# MAX State(ore=2, clay=51, obsidian=6, geode=20, ore_r=2, clay_r=8, obsidian_r=5, geode_r=6) 50 60 27 0
# MAX State(ore=3, clay=42, obsidian=10, geode=26, ore_r=2, clay_r=7, obsidian_r=6, geode_r=6) 50 56 28 0
# New Max Score 53 State(ore=3, clay=49, obsidian=9, geode=32, ore_r=2, clay_r=7, obsidian_r=6, geode_r=7) 28
# MAX State(ore=3, clay=49, obsidian=9, geode=32, ore_r=2, clay_r=7, obsidian_r=6, geode_r=7) 53 56 29 0
# New Max Score 55 State(ore=3, clay=56, obsidian=8, geode=39, ore_r=2, clay_r=7, obsidian_r=6, geode_r=8) 29
# MAX State(ore=3, clay=56, obsidian=8, geode=39, ore_r=2, clay_r=7, obsidian_r=6, geode_r=8) 55 56 30 0
# New Max Score 56 State(ore=3, clay=63, obsidian=7, geode=47, ore_r=2, clay_r=7, obsidian_r=6, geode_r=9) 30
# MAX State(ore=3, clay=63, obsidian=7, geode=47, ore_r=2, clay_r=7, obsidian_r=6, geode_r=9) 56 56 31 0
# MAX State(ore=3, clay=70, obsidian=6, geode=56, ore_r=2, clay_r=7, obsidian_r=6, geode_r=10) 56 56 32 0
# ================================================================================
# New Max Score 14 State(ore=12, clay=9, obsidian=4, geode=0, ore_r=3, clay_r=4, obsidian_r=4, geode_r=1) 17
# MAX State(ore=6, clay=16, obsidian=8, geode=1, ore_r=3, clay_r=6, obsidian_r=5, geode_r=1) 14 92 19 0
# New Max Score 26 State(ore=8, clay=21, obsidian=6, geode=2, ore_r=4, clay_r=6, obsidian_r=6, geode_r=2) 19
# MAX State(ore=8, clay=21, obsidian=6, geode=2, ore_r=4, clay_r=6, obsidian_r=6, geode_r=2) 26 92 20 0
# MAX State(ore=9, clay=23, obsidian=10, geode=4, ore_r=3, clay_r=6, obsidian_r=6, geode_r=2) 26 81 21 0
# New Max Score 36 State(ore=6, clay=21, obsidian=7, geode=6, ore_r=3, clay_r=6, obsidian_r=7, geode_r=3) 21
# MAX State(ore=6, clay=21, obsidian=7, geode=6, ore_r=3, clay_r=6, obsidian_r=7, geode_r=3) 36 81 22 0
# MAX State(ore=14, clay=31, obsidian=12, geode=9, ore_r=4, clay_r=6, obsidian_r=7, geode_r=3) 36 72 23 0
# New Max Score 44 State(ore=15, clay=37, obsidian=7, geode=12, ore_r=4, clay_r=6, obsidian_r=7, geode_r=4) 23
# MAX State(ore=15, clay=37, obsidian=7, geode=12, ore_r=4, clay_r=6, obsidian_r=7, geode_r=4) 44 72 24 0
# New Max Score 50 State(ore=3, clay=43, obsidian=8, geode=15, ore_r=3, clay_r=7, obsidian_r=8, geode_r=5) 24
# MAX State(ore=3, clay=43, obsidian=8, geode=15, ore_r=3, clay_r=7, obsidian_r=8, geode_r=5) 50 71 25 0
# New Max Score 52 State(ore=3, clay=50, obsidian=8, geode=16, ore_r=3, clay_r=7, obsidian_r=8, geode_r=6) 25
# MAX State(ore=3, clay=50, obsidian=8, geode=16, ore_r=3, clay_r=7, obsidian_r=8, geode_r=6) 52 67 26 0
# MAX State(ore=6, clay=32, obsidian=16, geode=20, ore_r=3, clay_r=6, obsidian_r=9, geode_r=5) 50 65 26 0
# New Max Score 55 State(ore=6, clay=38, obsidian=13, geode=25, ore_r=3, clay_r=6, obsidian_r=9, geode_r=6) 26
# MAX State(ore=6, clay=38, obsidian=13, geode=25, ore_r=3, clay_r=6, obsidian_r=9, geode_r=6) 55 65 27 0
# New Max Score 59 State(ore=6, clay=44, obsidian=10, geode=31, ore_r=3, clay_r=6, obsidian_r=9, geode_r=7) 27
# MAX State(ore=6, clay=44, obsidian=10, geode=31, ore_r=3, clay_r=6, obsidian_r=9, geode_r=7) 59 65 28 0
# New Max Score 60 State(ore=6, clay=50, obsidian=9, geode=36, ore_r=3, clay_r=6, obsidian_r=9, geode_r=8) 28
# MAX State(ore=6, clay=50, obsidian=9, geode=36, ore_r=3, clay_r=6, obsidian_r=9, geode_r=8) 60 63 29 0
# MAX State(ore=17, clay=43, obsidian=18, geode=38, ore_r=4, clay_r=6, obsidian_r=10, geode_r=7) 59 62 29 0
# New Max Score 61 State(ore=18, clay=49, obsidian=16, geode=45, ore_r=4, clay_r=6, obsidian_r=10, geode_r=8) 29
# MAX State(ore=18, clay=49, obsidian=16, geode=45, ore_r=4, clay_r=6, obsidian_r=10, geode_r=8) 61 62 30 0
# New Max Score 62 State(ore=19, clay=55, obsidian=14, geode=53, ore_r=4, clay_r=6, obsidian_r=10, geode_r=9) 30
# MAX State(ore=19, clay=55, obsidian=14, geode=53, ore_r=4, clay_r=6, obsidian_r=10, geode_r=9) 62 62 31 0
# MAX State(ore=20, clay=61, obsidian=12, geode=62, ore_r=4, clay_r=6, obsidian_r=10, geode_r=10) 62 62 32 0
# [56, 62, 1]
# 3472
# ================================================================================
# New Max Score 11 State(ore=1, clay=12, obsidian=2, geode=0, ore_r=1, clay_r=3, obsidian_r=2, geode_r=1) 20
# MAX State(ore=2, clay=15, obsidian=4, geode=1, ore_r=1, clay_r=3, obsidian_r=2, geode_r=1) 11 56 22 0
# MAX State(ore=1, clay=7, obsidian=6, geode=2, ore_r=1, clay_r=3, obsidian_r=3, geode_r=1) 11 47 23 0
# New Max Score 18 State(ore=2, clay=15, obsidian=4, geode=2, ore_r=2, clay_r=5, obsidian_r=4, geode_r=2) 23
# MAX State(ore=5, clay=19, obsidian=6, geode=4, ore_r=2, clay_r=5, obsidian_r=4, geode_r=2) 18 39 25 0
# New Max Score 24 State(ore=3, clay=24, obsidian=4, geode=6, ore_r=2, clay_r=5, obsidian_r=4, geode_r=3) 25
# MAX State(ore=3, clay=24, obsidian=4, geode=6, ore_r=2, clay_r=5, obsidian_r=4, geode_r=3) 24 39 26 0
# MAX State(ore=2, clay=19, obsidian=8, geode=9, ore_r=2, clay_r=5, obsidian_r=5, geode_r=3) 24 34 27 0
# New Max Score 28 State(ore=2, clay=35, obsidian=4, geode=12, ore_r=2, clay_r=5, obsidian_r=4, geode_r=4) 27
# MAX State(ore=2, clay=35, obsidian=4, geode=12, ore_r=2, clay_r=5, obsidian_r=4, geode_r=4) 28 34 28 0
# New Max Score 30 State(ore=10, clay=25, obsidian=6, geode=15, ore_r=3, clay_r=6, obsidian_r=6, geode_r=5) 28
# MAX State(ore=10, clay=25, obsidian=6, geode=15, ore_r=3, clay_r=6, obsidian_r=6, geode_r=5) 30 33 29 0
# MAX State(ore=4, clay=45, obsidian=6, geode=18, ore_r=3, clay_r=7, obsidian_r=6, geode_r=6) 30 31 30 0
# MAX State(ore=12, clay=34, obsidian=12, geode=20, ore_r=4, clay_r=7, obsidian_r=7, geode_r=5) 30 31 30 0
# New Max Score 31 State(ore=12, clay=41, obsidian=11, geode=25, ore_r=4, clay_r=7, obsidian_r=7, geode_r=6) 30
# MAX State(ore=12, clay=41, obsidian=11, geode=25, ore_r=4, clay_r=7, obsidian_r=7, geode_r=6) 31 31 31 0
# MAX State(ore=12, clay=48, obsidian=10, geode=31, ore_r=4, clay_r=7, obsidian_r=7, geode_r=7) 31 31 32 0
# ================================================================================
# New Max Score 6 State(ore=13, clay=36, obsidian=4, geode=0, ore_r=4, clay_r=11, obsidian_r=4, geode_r=1) 25
# MAX State(ore=9, clay=12, obsidian=6, geode=1, ore_r=3, clay_r=6, obsidian_r=4, geode_r=1) 6 16 27 0
# MAX State(ore=19, clay=42, obsidian=12, geode=2, ore_r=4, clay_r=11, obsidian_r=5, geode_r=1) 6 12 28 0
# New Max Score 9 State(ore=16, clay=35, obsidian=6, geode=3, ore_r=4, clay_r=11, obsidian_r=6, geode_r=2) 28
# MAX State(ore=16, clay=35, obsidian=6, geode=3, ore_r=4, clay_r=11, obsidian_r=6, geode_r=2) 9 12 29 0
# MAX State(ore=22, clay=28, obsidian=12, geode=5, ore_r=4, clay_r=10, obsidian_r=7, geode_r=2) 9 10 30 0
# MAX State(ore=22, clay=41, obsidian=18, geode=7, ore_r=4, clay_r=11, obsidian_r=7, geode_r=2) 9 9 31 0
# MAX State(ore=22, clay=52, obsidian=9, geode=9, ore_r=4, clay_r=11, obsidian_r=7, geode_r=3) 9 9 32 0
# ================================================================================
# New Max Score 9 State(ore=14, clay=28, obsidian=3, geode=0, ore_r=4, clay_r=9, obsidian_r=3, geode_r=1) 22
# MAX State(ore=14, clay=25, obsidian=6, geode=1, ore_r=4, clay_r=9, obsidian_r=4, geode_r=1) 9 37 24 0
# MAX State(ore=18, clay=28, obsidian=9, geode=2, ore_r=4, clay_r=9, obsidian_r=4, geode_r=1) 9 30 25 0
# New Max Score 14 State(ore=16, clay=19, obsidian=5, geode=2, ore_r=4, clay_r=9, obsidian_r=5, geode_r=2) 25
# MAX State(ore=19, clay=40, obsidian=8, geode=4, ore_r=5, clay_r=10, obsidian_r=5, geode_r=2) 14 24 27 0
# New Max Score 17 State(ore=18, clay=32, obsidian=6, geode=5, ore_r=5, clay_r=10, obsidian_r=6, geode_r=3) 27
# MAX State(ore=18, clay=32, obsidian=6, geode=5, ore_r=5, clay_r=10, obsidian_r=6, geode_r=3) 17 23 28 0
# MAX State(ore=14, clay=22, obsidian=12, geode=8, ore_r=4, clay_r=10, obsidian_r=7, geode_r=3) 17 20 29 0
# New Max Score 19 State(ore=16, clay=32, obsidian=8, geode=11, ore_r=4, clay_r=10, obsidian_r=7, geode_r=4) 29
# MAX State(ore=16, clay=32, obsidian=8, geode=11, ore_r=4, clay_r=10, obsidian_r=7, geode_r=4) 19 20 30 0
# MAX State(ore=27, clay=44, obsidian=12, geode=15, ore_r=5, clay_r=10, obsidian_r=7, geode_r=4) 19 19 31 0
# MAX State(ore=30, clay=54, obsidian=8, geode=19, ore_r=5, clay_r=10, obsidian_r=7, geode_r=5) 19 19 32 0
# [31, 9, 19]
# 5301

# %% [markdown]
# OLD CODE
# ========

# %%
def analyze(blueprint, max_depth):
    Q = collections.deque()
    
    max_geode = 0
    max_score = [ 0 ] * 33
    prune_cnt = 0

    root = State(0, 0, 0, 0, 0, 1, 0, 0, 0)
    Q.append(root)

    earliest_geode = None

    while len(Q) > 0:
        v = Q.pop()  # BFS

        _, v_best_score = score(v, max_depth - v.depth, blueprint)
        
        if v.depth >= max_depth:
            continue
            
        if v_best_score < max_score[v.depth]:
            prune_cnt += 1
            continue

        #if (earliest_geode is None and v.geode) or (v.geode > 0 and earliest_geode > v.depth):
        #    earliest_geode = v.depth
        #    print("New earliest", max_geode, current_score, best_score, v)
        #elif v.geode == 0 and earliest_geode is not None and v.depth > earliest_geode:
        #    prune_cnt += 1
        #    continue

        next_states = list(next_state(v, blueprint))
        for child in next_states:
            current_score, best_score = score(child, max_depth - child.depth, blueprint)
            if max_geode < child.geode:
                print("New max geode", max_geode, current_score, best_score, child)
                max_geode = child.geode
            if max_score[child.depth] < current_score:
                print("New max score", max_geode, current_score, best_score, child)
                max_score[child.depth] = current_score
            Q.append(child)

    print("Pruned", prune_cnt)
    return max_geode

def part2(puzzle_input):
    blueprints = read_input(puzzle_input)
    total_quality = [1,1,1]
    for ii, blueprint in enumerate(blueprints[0:3]):
        print("-"*40)
        max_geodes = analyze(blueprint, 32)
        total_quality[ii] = max_geodes
            
    print(total_quality)
    return total_quality[0] * total_quality[1] * total_quality[2]

def test_part2():
    ans = part2(os.path.join(os.path.join("..", "dat", "day19_test.txt")))
    #print(ans)
    #assert ans == (56*62)

test_part2()

#print("X"*40)
#ans = part2(os.path.join(os.path.join("..", "dat", "day19.txt")))
#print(ans) # NOT 5130 (too low)
# Out:
# ----------------------------------------
# New max score 0 1 1 State(depth=31, ore=1, clay=167, obsidian=2, geode=0, ore_r=1, clay_r=11, obsidian_r=2, geode_r=1)
# New max geode 0 1 1 State(depth=32, ore=2, clay=178, obsidian=4, geode=1, ore_r=1, clay_r=11, obsidian_r=2, geode_r=1)
# New max score 1 1 1 State(depth=32, ore=2, clay=178, obsidian=4, geode=1, ore_r=1, clay_r=11, obsidian_r=2, geode_r=1)
# New max score 1 2 3 State(depth=30, ore=2, clay=152, obsidian=2, geode=0, ore_r=1, clay_r=10, obsidian_r=2, geode_r=1)
# New max score 1 2 2 State(depth=31, ore=3, clay=162, obsidian=4, geode=1, ore_r=1, clay_r=10, obsidian_r=2, geode_r=1)
# New max geode 1 2 2 State(depth=32, ore=2, clay=173, obsidian=6, geode=2, ore_r=1, clay_r=11, obsidian_r=2, geode_r=1)
# New max score 2 2 2 State(depth=32, ore=2, clay=173, obsidian=6, geode=2, ore_r=1, clay_r=11, obsidian_r=2, geode_r=1)
# New max score 2 3 6 State(depth=29, ore=1, clay=139, obsidian=2, geode=0, ore_r=1, clay_r=10, obsidian_r=2, geode_r=1)
# New max score 2 3 4 State(depth=30, ore=2, clay=149, obsidian=4, geode=1, ore_r=1, clay_r=10, obsidian_r=2, geode_r=1)
# New max score 2 3 3 State(depth=31, ore=3, clay=159, obsidian=6, geode=2, ore_r=1, clay_r=10, obsidian_r=2, geode_r=1)
# New max geode 2 3 3 State(depth=32, ore=2, clay=170, obsidian=8, geode=3, ore_r=1, clay_r=11, obsidian_r=2, geode_r=1)
# New max score 3 3 3 State(depth=32, ore=2, clay=170, obsidian=8, geode=3, ore_r=1, clay_r=11, obsidian_r=2, geode_r=1)
# New max score 3 4 10 State(depth=28, ore=2, clay=125, obsidian=2, geode=0, ore_r=1, clay_r=9, obsidian_r=2, geode_r=1)
# New max score 3 4 7 State(depth=29, ore=3, clay=134, obsidian=4, geode=1, ore_r=1, clay_r=9, obsidian_r=2, geode_r=1)
# New max score 3 4 5 State(depth=30, ore=2, clay=144, obsidian=6, geode=2, ore_r=1, clay_r=10, obsidian_r=2, geode_r=1)
# New max score 3 4 4 State(depth=31, ore=3, clay=154, obsidian=8, geode=3, ore_r=1, clay_r=10, obsidian_r=2, geode_r=1)
# New max geode 3 4 4 State(depth=32, ore=2, clay=165, obsidian=10, geode=4, ore_r=1, clay_r=11, obsidian_r=2, geode_r=1)
# New max score 4 4 4 State(depth=32, ore=2, clay=165, obsidian=10, geode=4, ore_r=1, clay_r=11, obsidian_r=2, geode_r=1)
# New max score 4 5 15 State(depth=27, ore=1, clay=113, obsidian=2, geode=0, ore_r=1, clay_r=9, obsidian_r=2, geode_r=1)
# New max score 4 5 11 State(depth=28, ore=2, clay=122, obsidian=4, geode=1, ore_r=1, clay_r=9, obsidian_r=2, geode_r=1)
# New max score 4 5 8 State(depth=29, ore=3, clay=131, obsidian=6, geode=2, ore_r=1, clay_r=9, obsidian_r=2, geode_r=1)
# New max score 4 5 6 State(depth=30, ore=2, clay=141, obsidian=8, geode=3, ore_r=1, clay_r=10, obsidian_r=2, geode_r=1)
# New max score 4 5 5 State(depth=31, ore=3, clay=151, obsidian=10, geode=4, ore_r=1, clay_r=10, obsidian_r=2, geode_r=1)
# New max score 4 6 6 State(depth=31, ore=1, clay=151, obsidian=3, geode=4, ore_r=1, clay_r=10, obsidian_r=2, geode_r=2)
# New max geode 4 6 6 State(depth=32, ore=2, clay=161, obsidian=5, geode=6, ore_r=1, clay_r=10, obsidian_r=2, geode_r=2)
# New max score 6 6 6 State(depth=32, ore=2, clay=161, obsidian=5, geode=6, ore_r=1, clay_r=10, obsidian_r=2, geode_r=2)
# New max score 6 7 8 State(depth=30, ore=2, clay=137, obsidian=3, geode=3, ore_r=1, clay_r=9, obsidian_r=2, geode_r=2)
# New max score 6 7 7 State(depth=31, ore=3, clay=146, obsidian=5, geode=5, ore_r=1, clay_r=9, obsidian_r=2, geode_r=2)
# New max geode 6 7 7 State(depth=32, ore=2, clay=156, obsidian=7, geode=7, ore_r=1, clay_r=10, obsidian_r=2, geode_r=2)
# New max score 7 7 7 State(depth=32, ore=2, clay=156, obsidian=7, geode=7, ore_r=1, clay_r=10, obsidian_r=2, geode_r=2)
# New max score 7 6 21 State(depth=26, ore=2, clay=100, obsidian=2, geode=0, ore_r=1, clay_r=8, obsidian_r=2, geode_r=1)
# New max score 7 6 16 State(depth=27, ore=3, clay=108, obsidian=4, geode=1, ore_r=1, clay_r=8, obsidian_r=2, geode_r=1)
# New max score 7 6 12 State(depth=28, ore=2, clay=117, obsidian=6, geode=2, ore_r=1, clay_r=9, obsidian_r=2, geode_r=1)
# New max score 7 6 9 State(depth=29, ore=3, clay=126, obsidian=8, geode=3, ore_r=1, clay_r=9, obsidian_r=2, geode_r=1)
# New max score 7 8 9 State(depth=30, ore=2, clay=135, obsidian=3, geode=4, ore_r=1, clay_r=9, obsidian_r=2, geode_r=2)
# New max score 7 8 8 State(depth=31, ore=3, clay=144, obsidian=5, geode=6, ore_r=1, clay_r=9, obsidian_r=2, geode_r=2)
# New max geode 7 8 8 State(depth=32, ore=2, clay=154, obsidian=7, geode=8, ore_r=1, clay_r=10, obsidian_r=2, geode_r=2)
# New max score 8 8 8 State(depth=32, ore=2, clay=154, obsidian=7, geode=8, ore_r=1, clay_r=10, obsidian_r=2, geode_r=2)
# New max score 8 7 28 State(depth=25, ore=1, clay=89, obsidian=2, geode=0, ore_r=1, clay_r=8, obsidian_r=2, geode_r=1)
# New max score 8 7 22 State(depth=26, ore=2, clay=97, obsidian=4, geode=1, ore_r=1, clay_r=8, obsidian_r=2, geode_r=1)
# New max score 8 7 17 State(depth=27, ore=3, clay=105, obsidian=6, geode=2, ore_r=1, clay_r=8, obsidian_r=2, geode_r=1)
# New max score 8 7 13 State(depth=28, ore=2, clay=114, obsidian=8, geode=3, ore_r=1, clay_r=9, obsidian_r=2, geode_r=1)
# New max score 8 7 10 State(depth=29, ore=3, clay=123, obsidian=10, geode=4, ore_r=1, clay_r=9, obsidian_r=2, geode_r=1)
# New max score 8 10 13 State(depth=29, ore=1, clay=123, obsidian=3, geode=4, ore_r=1, clay_r=9, obsidian_r=2, geode_r=2)
# New max score 8 10 11 State(depth=30, ore=2, clay=132, obsidian=5, geode=6, ore_r=1, clay_r=9, obsidian_r=2, geode_r=2)
# New max score 8 10 10 State(depth=31, ore=3, clay=141, obsidian=7, geode=8, ore_r=1, clay_r=9, obsidian_r=2, geode_r=2)
# New max geode 8 10 10 State(depth=32, ore=2, clay=151, obsidian=9, geode=10, ore_r=1, clay_r=10, obsidian_r=2, geode_r=2)
# New max score 10 10 10 State(depth=32, ore=2, clay=151, obsidian=9, geode=10, ore_r=1, clay_r=10, obsidian_r=2, geode_r=2)
# New max score 10 11 11 State(depth=31, ore=1, clay=138, obsidian=2, geode=8, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max geode 10 11 11 State(depth=32, ore=2, clay=147, obsidian=4, geode=11, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max score 11 11 11 State(depth=32, ore=2, clay=147, obsidian=4, geode=11, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max score 11 11 17 State(depth=28, ore=2, clay=110, obsidian=3, geode=3, ore_r=1, clay_r=8, obsidian_r=2, geode_r=2)
# New max score 11 11 14 State(depth=29, ore=3, clay=118, obsidian=5, geode=5, ore_r=1, clay_r=8, obsidian_r=2, geode_r=2)
# New max score 11 11 12 State(depth=30, ore=2, clay=127, obsidian=7, geode=7, ore_r=1, clay_r=9, obsidian_r=2, geode_r=2)
# New max score 11 12 12 State(depth=31, ore=1, clay=136, obsidian=2, geode=9, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max geode 11 12 12 State(depth=32, ore=2, clay=145, obsidian=4, geode=12, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max score 12 12 12 State(depth=32, ore=2, clay=145, obsidian=4, geode=12, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max score 12 8 36 State(depth=24, ore=2, clay=77, obsidian=2, geode=0, ore_r=1, clay_r=7, obsidian_r=2, geode_r=1)
# New max score 12 8 29 State(depth=25, ore=3, clay=84, obsidian=4, geode=1, ore_r=1, clay_r=7, obsidian_r=2, geode_r=1)
# New max score 12 8 23 State(depth=26, ore=2, clay=92, obsidian=6, geode=2, ore_r=1, clay_r=8, obsidian_r=2, geode_r=1)
# New max score 12 8 18 State(depth=27, ore=3, clay=100, obsidian=8, geode=3, ore_r=1, clay_r=8, obsidian_r=2, geode_r=1)
# New max score 12 12 18 State(depth=28, ore=2, clay=108, obsidian=3, geode=4, ore_r=1, clay_r=8, obsidian_r=2, geode_r=2)
# New max score 12 12 15 State(depth=29, ore=3, clay=116, obsidian=5, geode=6, ore_r=1, clay_r=8, obsidian_r=2, geode_r=2)
# New max score 12 12 13 State(depth=30, ore=2, clay=125, obsidian=7, geode=8, ore_r=1, clay_r=9, obsidian_r=2, geode_r=2)
# New max score 12 13 13 State(depth=31, ore=1, clay=134, obsidian=2, geode=10, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max geode 12 13 13 State(depth=32, ore=2, clay=143, obsidian=4, geode=13, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max score 13 13 13 State(depth=32, ore=2, clay=143, obsidian=4, geode=13, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max score 13 14 15 State(depth=30, ore=1, clay=105, obsidian=4, geode=8, ore_r=1, clay_r=7, obsidian_r=3, geode_r=3)
# New max score 13 14 14 State(depth=31, ore=2, clay=112, obsidian=7, geode=11, ore_r=1, clay_r=7, obsidian_r=3, geode_r=3)
# New max geode 13 14 14 State(depth=32, ore=3, clay=119, obsidian=10, geode=14, ore_r=1, clay_r=7, obsidian_r=3, geode_r=3)
# New max score 14 14 14 State(depth=32, ore=3, clay=119, obsidian=10, geode=14, ore_r=1, clay_r=7, obsidian_r=3, geode_r=3)
# New max score 14 9 45 State(depth=23, ore=1, clay=67, obsidian=2, geode=0, ore_r=1, clay_r=7, obsidian_r=2, geode_r=1)
# New max score 14 9 37 State(depth=24, ore=2, clay=74, obsidian=4, geode=1, ore_r=1, clay_r=7, obsidian_r=2, geode_r=1)
# New max score 14 9 30 State(depth=25, ore=3, clay=81, obsidian=6, geode=2, ore_r=1, clay_r=7, obsidian_r=2, geode_r=1)
# New max score 14 9 24 State(depth=26, ore=2, clay=89, obsidian=8, geode=3, ore_r=1, clay_r=8, obsidian_r=2, geode_r=1)
# New max score 14 9 19 State(depth=27, ore=3, clay=97, obsidian=10, geode=4, ore_r=1, clay_r=8, obsidian_r=2, geode_r=1)
# New max score 14 14 24 State(depth=27, ore=1, clay=97, obsidian=3, geode=4, ore_r=1, clay_r=8, obsidian_r=2, geode_r=2)
# New max score 14 14 20 State(depth=28, ore=2, clay=105, obsidian=5, geode=6, ore_r=1, clay_r=8, obsidian_r=2, geode_r=2)
# New max score 14 14 17 State(depth=29, ore=3, clay=113, obsidian=7, geode=8, ore_r=1, clay_r=8, obsidian_r=2, geode_r=2)
# New max score 14 15 15 State(depth=31, ore=1, clay=131, obsidian=4, geode=12, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max geode 14 15 15 State(depth=32, ore=2, clay=140, obsidian=6, geode=15, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max score 15 15 15 State(depth=32, ore=2, clay=140, obsidian=6, geode=15, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max score 15 16 17 State(depth=30, ore=2, clay=121, obsidian=2, geode=10, ore_r=1, clay_r=8, obsidian_r=2, geode_r=3)
# New max score 15 16 16 State(depth=31, ore=3, clay=129, obsidian=4, geode=13, ore_r=1, clay_r=8, obsidian_r=2, geode_r=3)
# New max geode 15 16 16 State(depth=32, ore=2, clay=138, obsidian=6, geode=16, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max score 16 16 16 State(depth=32, ore=2, clay=138, obsidian=6, geode=16, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max score 16 17 20 State(depth=29, ore=1, clay=110, obsidian=2, geode=8, ore_r=1, clay_r=8, obsidian_r=2, geode_r=3)
# New max score 16 17 18 State(depth=30, ore=2, clay=118, obsidian=4, geode=11, ore_r=1, clay_r=8, obsidian_r=2, geode_r=3)
# New max score 16 17 17 State(depth=31, ore=3, clay=126, obsidian=6, geode=14, ore_r=1, clay_r=8, obsidian_r=2, geode_r=3)
# New max geode 16 17 17 State(depth=32, ore=2, clay=135, obsidian=8, geode=17, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max score 17 17 17 State(depth=32, ore=2, clay=135, obsidian=8, geode=17, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max score 17 15 30 State(depth=26, ore=2, clay=85, obsidian=3, geode=3, ore_r=1, clay_r=7, obsidian_r=2, geode_r=2)
# New max score 17 15 25 State(depth=27, ore=3, clay=92, obsidian=5, geode=5, ore_r=1, clay_r=7, obsidian_r=2, geode_r=2)
# New max score 17 15 21 State(depth=28, ore=2, clay=100, obsidian=7, geode=7, ore_r=1, clay_r=8, obsidian_r=2, geode_r=2)
# New max score 17 18 21 State(depth=29, ore=1, clay=108, obsidian=2, geode=9, ore_r=1, clay_r=8, obsidian_r=2, geode_r=3)
# New max score 17 18 19 State(depth=30, ore=2, clay=116, obsidian=4, geode=12, ore_r=1, clay_r=8, obsidian_r=2, geode_r=3)
# New max score 17 18 18 State(depth=31, ore=3, clay=124, obsidian=6, geode=15, ore_r=1, clay_r=8, obsidian_r=2, geode_r=3)
# New max geode 17 18 18 State(depth=32, ore=2, clay=133, obsidian=8, geode=18, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max score 18 18 18 State(depth=32, ore=2, clay=133, obsidian=8, geode=18, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max score 18 10 55 State(depth=22, ore=2, clay=56, obsidian=2, geode=0, ore_r=1, clay_r=6, obsidian_r=2, geode_r=1)
# New max score 18 10 46 State(depth=23, ore=3, clay=62, obsidian=4, geode=1, ore_r=1, clay_r=6, obsidian_r=2, geode_r=1)
# New max score 18 10 38 State(depth=24, ore=2, clay=69, obsidian=6, geode=2, ore_r=1, clay_r=7, obsidian_r=2, geode_r=1)
# New max score 18 10 31 State(depth=25, ore=3, clay=76, obsidian=8, geode=3, ore_r=1, clay_r=7, obsidian_r=2, geode_r=1)
# New max score 18 16 31 State(depth=26, ore=2, clay=83, obsidian=3, geode=4, ore_r=1, clay_r=7, obsidian_r=2, geode_r=2)
# New max score 18 16 26 State(depth=27, ore=3, clay=90, obsidian=5, geode=6, ore_r=1, clay_r=7, obsidian_r=2, geode_r=2)
# New max score 18 16 22 State(depth=28, ore=2, clay=98, obsidian=7, geode=8, ore_r=1, clay_r=8, obsidian_r=2, geode_r=2)
# New max score 18 19 22 State(depth=29, ore=1, clay=106, obsidian=2, geode=10, ore_r=1, clay_r=8, obsidian_r=2, geode_r=3)
# New max score 18 19 20 State(depth=30, ore=2, clay=114, obsidian=4, geode=13, ore_r=1, clay_r=8, obsidian_r=2, geode_r=3)
# New max score 18 19 19 State(depth=31, ore=3, clay=122, obsidian=6, geode=16, ore_r=1, clay_r=8, obsidian_r=2, geode_r=3)
# New max geode 18 19 19 State(depth=32, ore=2, clay=131, obsidian=8, geode=19, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max score 19 19 19 State(depth=32, ore=2, clay=131, obsidian=8, geode=19, ore_r=1, clay_r=9, obsidian_r=2, geode_r=3)
# New max score 19 20 26 State(depth=28, ore=1, clay=78, obsidian=4, geode=8, ore_r=1, clay_r=6, obsidian_r=3, geode_r=3)
# New max score 19 20 23 State(depth=29, ore=2, clay=84, obsidian=7, geode=11, ore_r=1, clay_r=6, obsidian_r=3, geode_r=3)
# New max score 19 20 21 State(depth=30, ore=3, clay=90, obsidian=10, geode=14, ore_r=1, clay_r=6, obsidian_r=3, geode_r=3)
# New max score 19 22 23 State(depth=30, ore=1, clay=90, obsidian=3, geode=14, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 19 22 22 State(depth=31, ore=2, clay=96, obsidian=6, geode=18, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max geode 19 22 22 State(depth=32, ore=3, clay=102, obsidian=9, geode=22, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 22 22 22 State(depth=32, ore=3, clay=102, obsidian=9, geode=22, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 22 11 66 State(depth=21, ore=1, clay=47, obsidian=2, geode=0, ore_r=1, clay_r=6, obsidian_r=2, geode_r=1)
# New max score 22 11 56 State(depth=22, ore=2, clay=53, obsidian=4, geode=1, ore_r=1, clay_r=6, obsidian_r=2, geode_r=1)
# New max score 22 11 47 State(depth=23, ore=3, clay=59, obsidian=6, geode=2, ore_r=1, clay_r=6, obsidian_r=2, geode_r=1)
# New max score 22 11 39 State(depth=24, ore=2, clay=66, obsidian=8, geode=3, ore_r=1, clay_r=7, obsidian_r=2, geode_r=1)
# New max score 22 11 32 State(depth=25, ore=3, clay=73, obsidian=10, geode=4, ore_r=1, clay_r=7, obsidian_r=2, geode_r=1)
# New max score 22 18 39 State(depth=25, ore=1, clay=73, obsidian=3, geode=4, ore_r=1, clay_r=7, obsidian_r=2, geode_r=2)
# New max score 22 18 33 State(depth=26, ore=2, clay=80, obsidian=5, geode=6, ore_r=1, clay_r=7, obsidian_r=2, geode_r=2)
# New max score 22 18 28 State(depth=27, ore=3, clay=87, obsidian=7, geode=8, ore_r=1, clay_r=7, obsidian_r=2, geode_r=2)
# New max score 22 21 24 State(depth=29, ore=1, clay=103, obsidian=4, geode=12, ore_r=1, clay_r=8, obsidian_r=2, geode_r=3)
# New max score 22 22 28 State(depth=28, ore=2, clay=94, obsidian=2, geode=10, ore_r=1, clay_r=7, obsidian_r=2, geode_r=3)
# New max score 22 22 25 State(depth=29, ore=3, clay=101, obsidian=4, geode=13, ore_r=1, clay_r=7, obsidian_r=2, geode_r=3)
# New max score 22 23 24 State(depth=30, ore=1, clay=87, obsidian=5, geode=15, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 22 23 23 State(depth=31, ore=2, clay=93, obsidian=8, geode=19, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max geode 22 23 23 State(depth=32, ore=3, clay=99, obsidian=11, geode=23, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 23 23 23 State(depth=32, ore=3, clay=99, obsidian=11, geode=23, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 23 24 25 State(depth=30, ore=1, clay=87, obsidian=3, geode=16, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 23 24 24 State(depth=31, ore=2, clay=93, obsidian=6, geode=20, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max geode 23 24 24 State(depth=32, ore=3, clay=99, obsidian=9, geode=24, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 24 24 24 State(depth=32, ore=3, clay=99, obsidian=9, geode=24, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 24 23 33 State(depth=27, ore=1, clay=84, obsidian=2, geode=8, ore_r=1, clay_r=7, obsidian_r=2, geode_r=3)
# New max score 24 23 29 State(depth=28, ore=2, clay=91, obsidian=4, geode=11, ore_r=1, clay_r=7, obsidian_r=2, geode_r=3)
# New max score 24 23 26 State(depth=29, ore=3, clay=98, obsidian=6, geode=14, ore_r=1, clay_r=7, obsidian_r=2, geode_r=3)
# New max score 24 19 47 State(depth=24, ore=2, clay=62, obsidian=3, geode=3, ore_r=1, clay_r=6, obsidian_r=2, geode_r=2)
# New max score 24 19 40 State(depth=25, ore=3, clay=68, obsidian=5, geode=5, ore_r=1, clay_r=6, obsidian_r=2, geode_r=2)
# New max score 24 19 34 State(depth=26, ore=2, clay=75, obsidian=7, geode=7, ore_r=1, clay_r=7, obsidian_r=2, geode_r=2)
# New max score 24 24 34 State(depth=27, ore=1, clay=82, obsidian=2, geode=9, ore_r=1, clay_r=7, obsidian_r=2, geode_r=3)
# New max score 24 24 30 State(depth=28, ore=2, clay=89, obsidian=4, geode=12, ore_r=1, clay_r=7, obsidian_r=2, geode_r=3)
# New max score 24 24 27 State(depth=29, ore=3, clay=96, obsidian=6, geode=15, ore_r=1, clay_r=7, obsidian_r=2, geode_r=3)
# New max score 24 25 25 State(depth=31, ore=1, clay=112, obsidian=3, geode=21, ore_r=1, clay_r=8, obsidian_r=2, geode_r=4)
# New max geode 24 25 25 State(depth=32, ore=2, clay=120, obsidian=5, geode=25, ore_r=1, clay_r=8, obsidian_r=2, geode_r=4)
# New max score 25 25 25 State(depth=32, ore=2, clay=120, obsidian=5, geode=25, ore_r=1, clay_r=8, obsidian_r=2, geode_r=4)
# New max score 25 25 26 State(depth=30, ore=1, clay=84, obsidian=5, geode=17, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 25 26 27 State(depth=30, ore=1, clay=84, obsidian=3, geode=18, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 25 26 26 State(depth=31, ore=2, clay=90, obsidian=6, geode=22, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max geode 25 26 26 State(depth=32, ore=3, clay=96, obsidian=9, geode=26, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 26 26 26 State(depth=32, ore=3, clay=96, obsidian=9, geode=26, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 26 12 78 State(depth=20, ore=2, clay=37, obsidian=2, geode=0, ore_r=1, clay_r=5, obsidian_r=2, geode_r=1)
# New max score 26 12 67 State(depth=21, ore=3, clay=42, obsidian=4, geode=1, ore_r=1, clay_r=5, obsidian_r=2, geode_r=1)
# New max score 26 12 57 State(depth=22, ore=2, clay=48, obsidian=6, geode=2, ore_r=1, clay_r=6, obsidian_r=2, geode_r=1)
# New max score 26 12 48 State(depth=23, ore=3, clay=54, obsidian=8, geode=3, ore_r=1, clay_r=6, obsidian_r=2, geode_r=1)
# New max score 26 20 48 State(depth=24, ore=2, clay=60, obsidian=3, geode=4, ore_r=1, clay_r=6, obsidian_r=2, geode_r=2)
# New max score 26 20 41 State(depth=25, ore=3, clay=66, obsidian=5, geode=6, ore_r=1, clay_r=6, obsidian_r=2, geode_r=2)
# New max score 26 20 35 State(depth=26, ore=2, clay=73, obsidian=7, geode=8, ore_r=1, clay_r=7, obsidian_r=2, geode_r=2)
# New max score 26 25 35 State(depth=27, ore=1, clay=80, obsidian=2, geode=10, ore_r=1, clay_r=7, obsidian_r=2, geode_r=3)
# New max score 26 25 31 State(depth=28, ore=2, clay=87, obsidian=4, geode=13, ore_r=1, clay_r=7, obsidian_r=2, geode_r=3)
# New max score 26 25 28 State(depth=29, ore=3, clay=94, obsidian=6, geode=16, ore_r=1, clay_r=7, obsidian_r=2, geode_r=3)
# New max score 26 27 28 State(depth=30, ore=1, clay=82, obsidian=3, geode=19, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 26 27 27 State(depth=31, ore=2, clay=88, obsidian=6, geode=23, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max geode 26 27 27 State(depth=32, ore=3, clay=94, obsidian=9, geode=27, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 27 27 27 State(depth=32, ore=3, clay=94, obsidian=9, geode=27, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 27 26 41 State(depth=26, ore=1, clay=53, obsidian=4, geode=8, ore_r=1, clay_r=5, obsidian_r=3, geode_r=3)
# New max score 27 26 36 State(depth=27, ore=2, clay=58, obsidian=7, geode=11, ore_r=1, clay_r=5, obsidian_r=3, geode_r=3)
# New max score 27 26 32 State(depth=28, ore=3, clay=63, obsidian=10, geode=14, ore_r=1, clay_r=5, obsidian_r=3, geode_r=3)
# New max score 27 30 36 State(depth=28, ore=1, clay=63, obsidian=3, geode=14, ore_r=1, clay_r=5, obsidian_r=3, geode_r=4)
# New max score 27 30 33 State(depth=29, ore=2, clay=68, obsidian=6, geode=18, ore_r=1, clay_r=5, obsidian_r=3, geode_r=4)
# New max score 27 30 31 State(depth=30, ore=3, clay=73, obsidian=9, geode=22, ore_r=1, clay_r=5, obsidian_r=3, geode_r=4)
# New max score 27 30 30 State(depth=31, ore=2, clay=79, obsidian=12, geode=26, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max geode 27 30 30 State(depth=32, ore=3, clay=85, obsidian=15, geode=30, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 30 30 30 State(depth=32, ore=3, clay=85, obsidian=15, geode=30, ore_r=1, clay_r=6, obsidian_r=3, geode_r=4)
# New max score 30 31 31 State(depth=31, ore=2, clay=78, obsidian=5, geode=26, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max geode 30 31 31 State(depth=32, ore=3, clay=83, obsidian=8, geode=31, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max score 31 31 31 State(depth=32, ore=3, clay=83, obsidian=8, geode=31, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max score 31 32 33 State(depth=30, ore=2, clay=48, obsidian=5, geode=20, ore_r=2, clay_r=6, obsidian_r=5, geode_r=6)
# New max score 31 32 32 State(depth=31, ore=4, clay=54, obsidian=10, geode=26, ore_r=2, clay_r=6, obsidian_r=5, geode_r=6)
# New max geode 31 32 32 State(depth=32, ore=4, clay=61, obsidian=15, geode=32, ore_r=2, clay_r=7, obsidian_r=5, geode_r=6)
# New max score 32 32 32 State(depth=32, ore=4, clay=61, obsidian=15, geode=32, ore_r=2, clay_r=7, obsidian_r=5, geode_r=6)
# New max score 32 13 91 State(depth=19, ore=1, clay=29, obsidian=2, geode=0, ore_r=1, clay_r=5, obsidian_r=2, geode_r=1)
# New max score 32 13 79 State(depth=20, ore=2, clay=34, obsidian=4, geode=1, ore_r=1, clay_r=5, obsidian_r=2, geode_r=1)
# New max score 32 13 68 State(depth=21, ore=3, clay=39, obsidian=6, geode=2, ore_r=1, clay_r=5, obsidian_r=2, geode_r=1)
# New max score 32 13 58 State(depth=22, ore=2, clay=45, obsidian=8, geode=3, ore_r=1, clay_r=6, obsidian_r=2, geode_r=1)
# New max score 32 13 49 State(depth=23, ore=3, clay=51, obsidian=10, geode=4, ore_r=1, clay_r=6, obsidian_r=2, geode_r=1)
# New max score 32 22 58 State(depth=23, ore=1, clay=51, obsidian=3, geode=4, ore_r=1, clay_r=6, obsidian_r=2, geode_r=2)
# New max score 32 22 50 State(depth=24, ore=2, clay=57, obsidian=5, geode=6, ore_r=1, clay_r=6, obsidian_r=2, geode_r=2)
# New max score 32 22 43 State(depth=25, ore=3, clay=63, obsidian=7, geode=8, ore_r=1, clay_r=6, obsidian_r=2, geode_r=2)
# New max score 32 27 37 State(depth=27, ore=1, clay=77, obsidian=4, geode=12, ore_r=1, clay_r=7, obsidian_r=2, geode_r=3)
# New max score 32 28 43 State(depth=26, ore=2, clay=69, obsidian=2, geode=10, ore_r=1, clay_r=6, obsidian_r=2, geode_r=3)
# New max score 32 28 38 State(depth=27, ore=3, clay=75, obsidian=4, geode=13, ore_r=1, clay_r=6, obsidian_r=2, geode_r=3)
# New max score 32 31 37 State(depth=28, ore=1, clay=60, obsidian=5, geode=15, ore_r=1, clay_r=5, obsidian_r=3, geode_r=4)
# New max score 32 31 34 State(depth=29, ore=2, clay=65, obsidian=8, geode=19, ore_r=1, clay_r=5, obsidian_r=3, geode_r=4)
# New max score 32 33 34 State(depth=30, ore=1, clay=70, obsidian=4, geode=23, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max score 32 33 33 State(depth=31, ore=2, clay=75, obsidian=7, geode=28, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max geode 32 33 33 State(depth=32, ore=3, clay=80, obsidian=10, geode=33, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max score 33 33 33 State(depth=32, ore=3, clay=80, obsidian=10, geode=33, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max score 33 32 38 State(depth=28, ore=1, clay=60, obsidian=3, geode=16, ore_r=1, clay_r=5, obsidian_r=3, geode_r=4)
# New max score 33 32 35 State(depth=29, ore=2, clay=65, obsidian=6, geode=20, ore_r=1, clay_r=5, obsidian_r=3, geode_r=4)
# New max score 33 29 50 State(depth=25, ore=1, clay=60, obsidian=2, geode=8, ore_r=1, clay_r=6, obsidian_r=2, geode_r=3)
# New max score 33 29 44 State(depth=26, ore=2, clay=66, obsidian=4, geode=11, ore_r=1, clay_r=6, obsidian_r=2, geode_r=3)
# New max score 33 29 39 State(depth=27, ore=3, clay=72, obsidian=6, geode=14, ore_r=1, clay_r=6, obsidian_r=2, geode_r=3)
# New max score 33 23 68 State(depth=22, ore=2, clay=41, obsidian=3, geode=3, ore_r=1, clay_r=5, obsidian_r=2, geode_r=2)
# New max score 33 23 59 State(depth=23, ore=3, clay=46, obsidian=5, geode=5, ore_r=1, clay_r=5, obsidian_r=2, geode_r=2)
# New max score 33 23 51 State(depth=24, ore=2, clay=52, obsidian=7, geode=7, ore_r=1, clay_r=6, obsidian_r=2, geode_r=2)
# New max score 33 30 51 State(depth=25, ore=1, clay=58, obsidian=2, geode=9, ore_r=1, clay_r=6, obsidian_r=2, geode_r=3)
# New max score 33 30 45 State(depth=26, ore=2, clay=64, obsidian=4, geode=12, ore_r=1, clay_r=6, obsidian_r=2, geode_r=3)
# New max score 33 30 40 State(depth=27, ore=3, clay=70, obsidian=6, geode=15, ore_r=1, clay_r=6, obsidian_r=2, geode_r=3)
# New max score 33 33 36 State(depth=29, ore=1, clay=84, obsidian=3, geode=21, ore_r=1, clay_r=7, obsidian_r=2, geode_r=4)
# New max score 33 33 39 State(depth=28, ore=1, clay=57, obsidian=5, geode=17, ore_r=1, clay_r=5, obsidian_r=3, geode_r=4)
# New max score 33 35 36 State(depth=30, ore=1, clay=67, obsidian=4, geode=25, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max score 33 35 35 State(depth=31, ore=2, clay=72, obsidian=7, geode=30, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max geode 33 35 35 State(depth=32, ore=3, clay=77, obsidian=10, geode=35, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max score 35 35 35 State(depth=32, ore=3, clay=77, obsidian=10, geode=35, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max score 35 34 40 State(depth=28, ore=1, clay=57, obsidian=3, geode=18, ore_r=1, clay_r=5, obsidian_r=3, geode_r=4)
# New max score 35 34 37 State(depth=29, ore=2, clay=62, obsidian=6, geode=22, ore_r=1, clay_r=5, obsidian_r=3, geode_r=4)
# New max score 35 14 105 State(depth=18, ore=2, clay=20, obsidian=2, geode=0, ore_r=1, clay_r=4, obsidian_r=2, geode_r=1)
# New max score 35 14 92 State(depth=19, ore=3, clay=24, obsidian=4, geode=1, ore_r=1, clay_r=4, obsidian_r=2, geode_r=1)
# New max score 35 14 80 State(depth=20, ore=2, clay=29, obsidian=6, geode=2, ore_r=1, clay_r=5, obsidian_r=2, geode_r=1)
# New max score 35 14 69 State(depth=21, ore=3, clay=34, obsidian=8, geode=3, ore_r=1, clay_r=5, obsidian_r=2, geode_r=1)
# New max score 35 24 69 State(depth=22, ore=2, clay=39, obsidian=3, geode=4, ore_r=1, clay_r=5, obsidian_r=2, geode_r=2)
# New max score 35 24 60 State(depth=23, ore=3, clay=44, obsidian=5, geode=6, ore_r=1, clay_r=5, obsidian_r=2, geode_r=2)
# New max score 35 24 52 State(depth=24, ore=2, clay=50, obsidian=7, geode=8, ore_r=1, clay_r=6, obsidian_r=2, geode_r=2)
# New max score 35 31 52 State(depth=25, ore=1, clay=56, obsidian=2, geode=10, ore_r=1, clay_r=6, obsidian_r=2, geode_r=3)
# New max score 35 31 46 State(depth=26, ore=2, clay=62, obsidian=4, geode=13, ore_r=1, clay_r=6, obsidian_r=2, geode_r=3)
# New max score 35 31 41 State(depth=27, ore=3, clay=68, obsidian=6, geode=16, ore_r=1, clay_r=6, obsidian_r=2, geode_r=3)
# New max score 35 36 37 State(depth=30, ore=1, clay=65, obsidian=4, geode=26, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max score 35 36 36 State(depth=31, ore=2, clay=70, obsidian=7, geode=31, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max geode 35 36 36 State(depth=32, ore=3, clay=75, obsidian=10, geode=36, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max score 36 36 36 State(depth=32, ore=3, clay=75, obsidian=10, geode=36, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max score 36 35 41 State(depth=28, ore=1, clay=55, obsidian=3, geode=19, ore_r=1, clay_r=5, obsidian_r=3, geode_r=4)
# New max score 36 35 38 State(depth=29, ore=2, clay=60, obsidian=6, geode=23, ore_r=1, clay_r=5, obsidian_r=3, geode_r=4)
# New max score 36 32 60 State(depth=24, ore=1, clay=30, obsidian=4, geode=8, ore_r=1, clay_r=4, obsidian_r=3, geode_r=3)
# New max score 36 32 53 State(depth=25, ore=2, clay=34, obsidian=7, geode=11, ore_r=1, clay_r=4, obsidian_r=3, geode_r=3)
# New max score 36 32 47 State(depth=26, ore=3, clay=38, obsidian=10, geode=14, ore_r=1, clay_r=4, obsidian_r=3, geode_r=3)
# New max score 36 38 53 State(depth=26, ore=1, clay=38, obsidian=3, geode=14, ore_r=1, clay_r=4, obsidian_r=3, geode_r=4)
# New max score 36 38 48 State(depth=27, ore=2, clay=42, obsidian=6, geode=18, ore_r=1, clay_r=4, obsidian_r=3, geode_r=4)
# New max score 36 38 44 State(depth=28, ore=3, clay=46, obsidian=9, geode=22, ore_r=1, clay_r=4, obsidian_r=3, geode_r=4)
# New max score 36 38 41 State(depth=29, ore=2, clay=51, obsidian=12, geode=26, ore_r=1, clay_r=5, obsidian_r=3, geode_r=4)
# New max score 36 38 39 State(depth=30, ore=3, clay=56, obsidian=15, geode=30, ore_r=1, clay_r=5, obsidian_r=3, geode_r=4)
# New max score 36 40 41 State(depth=30, ore=1, clay=56, obsidian=8, geode=30, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max score 36 40 40 State(depth=31, ore=2, clay=61, obsidian=11, geode=35, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max geode 36 40 40 State(depth=32, ore=3, clay=66, obsidian=14, geode=40, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max score 40 40 40 State(depth=32, ore=3, clay=66, obsidian=14, geode=40, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max score 40 41 44 State(depth=29, ore=2, clay=50, obsidian=5, geode=26, ore_r=1, clay_r=4, obsidian_r=3, geode_r=5)
# New max score 40 41 42 State(depth=30, ore=3, clay=54, obsidian=8, geode=31, ore_r=1, clay_r=4, obsidian_r=3, geode_r=5)
# New max score 40 41 41 State(depth=31, ore=2, clay=59, obsidian=11, geode=36, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max geode 40 41 41 State(depth=32, ore=3, clay=64, obsidian=14, geode=41, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max score 41 41 41 State(depth=32, ore=3, clay=64, obsidian=14, geode=41, ore_r=1, clay_r=5, obsidian_r=3, geode_r=5)
# New max score 41 42 42 State(depth=31, ore=2, clay=58, obsidian=4, geode=36, ore_r=1, clay_r=4, obsidian_r=3, geode_r=6)
# New max geode 41 42 42 State(depth=32, ore=3, clay=62, obsidian=7, geode=42, ore_r=1, clay_r=4, obsidian_r=3, geode_r=6)
# New max score 42 42 42 State(depth=32, ore=3, clay=62, obsidian=7, geode=42, ore_r=1, clay_r=4, obsidian_r=3, geode_r=6)
# New max score 42 40 46 State(depth=28, ore=1, clay=46, obsidian=4, geode=20, ore_r=1, clay_r=4, obsidian_r=3, geode_r=5)
# New max score 42 42 43 State(depth=30, ore=1, clay=54, obsidian=3, geode=30, ore_r=1, clay_r=4, obsidian_r=3, geode_r=6)
# New max score 42 43 44 State(depth=30, ore=2, clay=40, obsidian=5, geode=29, ore_r=2, clay_r=6, obsidian_r=5, geode_r=7)
# New max score 42 43 43 State(depth=31, ore=4, clay=46, obsidian=10, geode=36, ore_r=2, clay_r=6, obsidian_r=5, geode_r=7)
# New max geode 42 43 43 State(depth=32, ore=4, clay=53, obsidian=15, geode=43, ore_r=2, clay_r=7, obsidian_r=5, geode_r=7)
# New max score 43 43 43 State(depth=32, ore=4, clay=53, obsidian=15, geode=43, ore_r=2, clay_r=7, obsidian_r=5, geode_r=7)
# New max score 43 42 45 State(depth=29, ore=2, clay=31, obsidian=7, geode=24, ore_r=2, clay_r=6, obsidian_r=5, geode_r=6)
# New max score 43 44 45 State(depth=30, ore=2, clay=37, obsidian=5, geode=30, ore_r=2, clay_r=6, obsidian_r=5, geode_r=7)
# New max score 43 44 44 State(depth=31, ore=4, clay=43, obsidian=10, geode=37, ore_r=2, clay_r=6, obsidian_r=5, geode_r=7)
# New max geode 43 44 44 State(depth=32, ore=4, clay=50, obsidian=15, geode=44, ore_r=2, clay_r=7, obsidian_r=5, geode_r=7)
# New max score 44 44 44 State(depth=32, ore=4, clay=50, obsidian=15, geode=44, ore_r=2, clay_r=7, obsidian_r=5, geode_r=7)
# New max score 44 24 79 State(depth=21, ore=1, clay=33, obsidian=2, geode=2, ore_r=1, clay_r=5, obsidian_r=2, geode_r=2)
# New max score 44 25 80 State(depth=21, ore=1, clay=31, obsidian=2, geode=3, ore_r=1, clay_r=5, obsidian_r=2, geode_r=2)
# New max score 44 25 70 State(depth=22, ore=2, clay=36, obsidian=4, geode=5, ore_r=1, clay_r=5, obsidian_r=2, geode_r=2)
# New max score 44 25 61 State(depth=23, ore=3, clay=41, obsidian=6, geode=7, ore_r=1, clay_r=5, obsidian_r=2, geode_r=2)
# New max score 44 42 48 State(depth=28, ore=1, clay=43, obsidian=3, geode=22, ore_r=1, clay_r=4, obsidian_r=3, geode_r=5)
# New max score 44 33 61 State(depth=24, ore=1, clay=27, obsidian=3, geode=9, ore_r=1, clay_r=4, obsidian_r=3, geode_r=3)
# New max score 44 33 54 State(depth=25, ore=2, clay=31, obsidian=6, geode=12, ore_r=1, clay_r=4, obsidian_r=3, geode_r=3)
# New max score 44 45 45 State(depth=31, ore=2, clay=60, obsidian=4, geode=38, ore_r=2, clay_r=8, obsidian_r=4, geode_r=7)
# New max geode 44 45 45 State(depth=32, ore=4, clay=68, obsidian=8, geode=45, ore_r=2, clay_r=8, obsidian_r=4, geode_r=7)
# New max score 45 45 45 State(depth=32, ore=4, clay=68, obsidian=8, geode=45, ore_r=2, clay_r=8, obsidian_r=4, geode_r=7)
# New max score 45 45 48 State(depth=29, ore=3, clay=24, obsidian=5, geode=27, ore_r=2, clay_r=5, obsidian_r=5, geode_r=6)
# New max score 45 45 46 State(depth=30, ore=5, clay=29, obsidian=10, geode=33, ore_r=2, clay_r=5, obsidian_r=5, geode_r=6)
# New max score 45 46 46 State(depth=31, ore=2, clay=20, obsidian=9, geode=39, ore_r=2, clay_r=5, obsidian_r=6, geode_r=7)
# New max geode 45 46 46 State(depth=32, ore=4, clay=25, obsidian=15, geode=46, ore_r=2, clay_r=5, obsidian_r=6, geode_r=7)
# New max score 46 46 46 State(depth=32, ore=4, clay=25, obsidian=15, geode=46, ore_r=2, clay_r=5, obsidian_r=6, geode_r=7)
# New max score 46 46 47 State(depth=30, ore=3, clay=27, obsidian=5, geode=32, ore_r=2, clay_r=5, obsidian_r=5, geode_r=7)
# New max score 46 39 49 State(depth=27, ore=2, clay=30, obsidian=5, geode=14, ore_r=2, clay_r=6, obsidian_r=5, geode_r=5)
# New max score 46 40 50 State(depth=27, ore=2, clay=28, obsidian=5, geode=15, ore_r=2, clay_r=6, obsidian_r=5, geode_r=5)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 62
#      58     ans = part2(os.path.join(os.path.join("..", "dat", "day19_test.txt")))
#      59     #print(ans)
#      60     #assert ans == (56*62)
# ---> 62 test_part2()
#      64 #print("X"*40)
#      65 #ans = part2(os.path.join(os.path.join("..", "dat", "day19.txt")))
#      66 #print(ans) # NOT 5130 (too low)
#
# Cell In[20], line 58, in test_part2()
#      57 def test_part2():
# ---> 58     ans = part2(os.path.join(os.path.join("..", "dat", "day19_test.txt")))
#
# Cell In[20], line 51, in part2(puzzle_input)
#      49 for ii, blueprint in enumerate(blueprints[0:3]):
#      50     print("-"*40)
# ---> 51     max_geodes = analyze(blueprint, 32)
#      52     total_quality[ii] = max_geodes
#      54 print(total_quality)
#
# Cell In[20], line 32, in analyze(blueprint, max_depth)
#      23     continue
#      25 #if (earliest_geode is None and v.geode) or (v.geode > 0 and earliest_geode > v.depth):
#      26 #    earliest_geode = v.depth
#      27 #    print("New earliest", max_geode, current_score, best_score, v)
#      28 #elif v.geode == 0 and earliest_geode is not None and v.depth > earliest_geode:
#      29 #    prune_cnt += 1
#      30 #    continue
# ---> 32 next_states = list(next_state(v, blueprint))
#      33 for child in next_states:
#      34     current_score, best_score = score(child, max_depth - child.depth, blueprint)
#
# Cell In[19], line 19, in next_state(state, blueprint)
#      16     build_list = (None, "ore", "clay", "obsidian", "geode")
#      18 for build in build_list:
# ---> 19     remaining_ore = state.ore - blueprint.costs.get(build, {}).get("ore", 0)
#      20     remaining_clay = state.clay - blueprint.costs.get(build, {}).get("clay", 0)
#      21     remaining_obsidian = state.obsidian - blueprint.costs.get(build, {}).get("obsidian", 0)
#
# KeyboardInterrupt:

# %%
class State():
    def __init__(self, blueprint, prior_state=None):
        self.depth = 0
        self.inventory = {}
        self.robots = { "ore": 1 }
        #self.path = []
        self.prior_state = prior_state
        self.discovered = False
        self.blueprint = blueprint
        self.score = 0
        if prior_state is not None:
            self.depth = prior_state.depth + 1
            self.inventory.update(prior_state.inventory)
            self.robots.update(prior_state.robots)
            #self.path.extend(prior_state.path)

    def __lt__(self, other):
        # backwards for heapq descending order
        for item in ("geode", "obsidian", "clay", "ore"):
            if self.robots.get(item, 0) != other.robots.get(item, 0):
                return self.robots.get(item, 0) > other.robots.get(item, 0)

        return self.robots.get("geode", 0) > other.robots.get("geode", 0)
        
    def best_score(self, max_depth):
        n = max_depth - self.depth - 1 # rounds left
        geodes_per_robot = (n*(n+1))//2 # assume we build a geode robot per turn
        return (
            self.inventory.get("geode", 0) +  # current geodes
            ( self.robots.get("geode", 0) * (n+1) ) + # existing robots times rounds remaining
            geodes_per_robot # building a new geode robot for each remaining round
        )

    def next(self, max_depth):
        # Figure out what we can build, we can always build nothing
        available_builds = set([ None ])
        for robot, costs in self.blueprint.costs.items():
            satisifed = True
            for what, cnt in costs.items():
                if self.inventory.get(what, 0) < cnt:
                    satisifed = False
                    break
            else:
                available_builds.add(robot)

        # Branch for each available build
        for build in reversed((None, "ore", "clay", "obsidian", "geode")):
            if build not in available_builds:
                continue
            new_state = State(self.blueprint, self)
            #new_state.path.append(build)
            
            if build:                    
                for what, cnt in self.blueprint.costs[build].items():
                    new_state.inventory[what] = new_state.inventory.get(what, 0) - cnt
                    assert new_state.inventory.get(what, 0) >= 0

            for robot, count in new_state.robots.items():
                new_state.inventory[robot] = new_state.inventory.get(robot, 0) + count

            # Finish Building
            if build:
                new_state.robots[build] = new_state.robots.get(build, 0) + 1

            yield build, new_state

def analyze(blueprint, max_depth):
    max_ore = max([ xx.get("ore", 0) for xx in blueprint.costs.values() ])
    max_clay = max([ xx.get("clay", 0) for xx in blueprint.costs.values() ])
    max_obsidian = max([ xx.get("obsidian", 0) for xx in blueprint.costs.values() ])
    
    final_states = []
    max_score = 0
    first_geode = None
    max_geodes = 0
    cur_depth = 0
    prune_cnt = 0
    max_state = None
    earliest_geode = None
    root = State(blueprint)
    root._explored = True

    mode = "dfs"
    if mode in ("dfs", "bfs"):
        Q = collections.deque()
        Q.append(root)
    else:
        Q = []
        heapq.heappush(Q, (0, root))

    while len(Q) > 0:
        if mode == "bfs":
            v = Q.popleft()  # BFS
        elif mode == "dfs":
            v = Q.pop() # DFS
        elif mode == "pdfs":
            v = heapq.heappop(Q)[-1]
        else:
            raise ValueError

        if mode == "bfs" and v.depth > cur_depth:
            print(f"At depth {v.depth} pruned {prune_cnt}  {len(Q)}")
            cur_depth = v.depth
            prune_cnt = 0
        
        if v.score > max_score:
            print("New score max", v.score, v.depth, prune_cnt)
            max_score = max(v.score, max_score, prune_cnt)
        if v.inventory.get("geode", 0) > max_geodes:
            print("New geodes max", v.inventory.get("geode", 0), max_geodes)
            max_geodes = max(v.inventory.get("geode", 0), max_geodes, prune_cnt)
            max_state = v

        # Prune
        if max(max_score, max_geodes) >= v.best_score(max_depth):
            prune_cnt += 1
            continue

        #if child.depth > max_ore and sum(child.robots.values()) == 1:
        #    prune_cnt += 1
        #    continue

        #if child.depth > 20 and child.robots.get("geode", 0) == 0:
        #    prune_cnt += 1
        #    continue

        if v.depth >= max_depth:
            continue

        for build, child in v.next(max_depth):
            # Child is the state *after* the minute elapses.
            # Score is the number of geodes plus the number of geodes that would be produced
            # in the future
            n = max_depth - child.depth
            child.score = child.inventory.get("geode", 0) + child.robots.get("geode", 0) * n

            # Search
            if mode in ("bfs", "dfs"):
                Q.append(child)
            else:
                heapq.heappush(Q, (-1*child.score, child))


    return max_state, max_geodes

def part2(puzzle_input):
    blueprints = read_input(puzzle_input)
    total_quality = [1,1,1]
    for ii, blueprint in enumerate(blueprints[0:1]):
        print("-"*40)
        max_state, max_geodes = analyze(blueprint, 32)

        if max_state == None:
            print("RESULTS", ii+1, 0, 0)
            total_quality[ii] = 0
        else:
            print("RESULTS", ii+1, max_geodes, (ii+1)*max_geodes)
            print(max_state.inventory)
            print(max_state.robots)
            print(max_state.path)
            total_quality[ii] = max_geodes
            
    print(total_quality)
    return total_quality[0] * total_quality[1] * total_quality[2]

def test_part2():
    ans = part2(os.path.join(os.path.join("..", "dat", "day19_test.txt")))
    print(ans)
    assert ans == (56*62)

test_part2()

#print("X"*40)
#ans = part2(os.path.join(os.path.join("..", "dat", "day19.txt")))
#print(ans) # NOT 5130 (too low)
# Out:
# ----------------------------------------
# New score max 1 31 3335705
# RESULTS 1 0 0
# [0, 1, 1]
# 0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[24], line 171
#     168     print(ans)
#     169     assert ans == (56*62)
# --> 171 test_part2()
#     173 #print("X"*40)
#     174 #ans = part2(os.path.join(os.path.join("..", "dat", "day19.txt")))
#     175 #print(ans) # NOT 5130 (too low)
#
# Cell In[24], line 169, in test_part2()
#     167 ans = part2(os.path.join(os.path.join("..", "dat", "day19_test.txt")))
#     168 print(ans)
# --> 169 assert ans == (56*62)
#
# AssertionError:

# %%
class State():
    def __init__(self, prior_state=None):
        self.depth = 0
        self.inventory = {}
        self.robots = { "ore": 1 }
        self.path = []
        self.prior_state = prior_state
        self.discovered = False
        if prior_state is not None:
            self.depth = prior_state.depth + 1
            self.inventory.update(prior_state.inventory)
            self.robots.update(prior_state.robots)
            self.path.extend(prior_state.path)

def part1(puzzle_input):
    blueprints = read_input(puzzle_input)
    total_quality = 0
    for ii, blueprint in enumerate(blueprints):
        states = collections.deque()
        states.append(State())

        max_ore = max([ xx.get("ore", 0) for xx in blueprint.costs.values() ])
        max_clay = max([ xx.get("clay", 0) for xx in blueprint.costs.values() ])
        max_obsidian = max([ xx.get("obsidian", 0) for xx in blueprint.costs.values() ])
        

        final_states = []
        most_geodes = [ 0 ] * 24
        while len(states) > 0:
            state = states.popleft()
            state.discovered = True
            #print("Checking depth %s" % state.depth)
            if state.depth == 24:
                final_states.append(new_state)
                continue

            if state.inventory.get("geode", 0) < most_geodes[state.depth]:
                continue
            else:
                most_geodes[state.depth] = max(most_geodes[state.depth], state.inventory.get("geode", 0))
            
            #if state.inventory.get("ore", 0) > max_ore and state.depth < (24 - max_ore):
                # prune
            #    continue
            #if state.inventory.get("clay", 0) > max_clay and state.inventory.get("ore", 0) > blueprint.costs['obsidian'].get('ore', 0) and state.depth < (24 - max_clay):
                # prune
            #    continue
            #if state.inventory.get("obsidian", 0) > max_obsidian and state.inventory.get("ore", 0) > blueprint.costs['geode'].get('ore', 0) and state.depth < (24 -max_obsidian):
                # prune
            #    continue

            # Figure out what we can build, we can always build nothing
            available_builds = set([ None ])
            for robot, costs in blueprint.costs.items():
                satisifed = True
                for what, cnt in costs.items():
                    if state.inventory.get(what, 0) < cnt:
                        satisifed = False
                        break
                else:
                    available_builds.add(robot)

            # Branch for each available build
            for build in ("geode", "obsidian", "clay", "ore", None):
                if build not in available_builds:
                    continue

                new_state = State(state)
                new_state.path.append(build)
                if build:                    
                    for what, cnt in blueprint.costs[build].items():
                        new_state.inventory[what] = new_state.inventory.get(what, 0) - cnt
                        assert new_state.inventory.get(what, 0) >= 0

                for robot, count in new_state.robots.items():
                    new_state.inventory[robot] = new_state.inventory.get(robot, 0) + count

                # Finish Building
                if build:
                    new_state.robots[build] = new_state.robots.get(build, 0) + 1


                states.appendleft(new_state)

                            
        max_geodes = 0
        max_state = None
        for state in final_states:
            #print(state.inventory, state.path)
            if state.inventory.get("geode", 0) > max_geodes:
                max_state = state
                max_geodes = state.inventory.get("geode", 0)

        print("-"*40)
        if max_state == None:
            print("RESULTS", ii+1, 0, 0)
        else:
            print("RESULTS", ii+1, max_geodes, (ii+1)*max_geodes)
            print(max_state.inventory)
            print(max_state.robots)
            print(max_state.path)
            total_quality += ((ii+1)*max_geodes)

    return total_quality

def test_part1():
    ans = part1(os.path.join(os.path.join("..", "dat", "day19_test.txt")))
    print(ans)
    assert ans == 33

test_part1()

#print("X"*40)
#ans = part1(os.path.join(os.path.join("..", "dat", "day19.txt")))
#print(ans) # NOT 1174, NOT 1394 (1703!!!)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 111
#     108     print(ans)
#     109     assert ans == 33
# --> 111 test_part1()
#     113 #print("X"*40)
#     114 #ans = part1(os.path.join(os.path.join("..", "dat", "day19.txt")))
#     115 #print(ans) # NOT 1174, NOT 1394 (1703!!!)
#
# Cell In[3], line 107, in test_part1()
#     106 def test_part1():
# --> 107     ans = part1(os.path.join(os.path.join("..", "dat", "day19_test.txt")))
#     108     print(ans)
#     109     assert ans == 33
#
# Cell In[3], line 68, in part1(puzzle_input)
#      65 if build not in available_builds:
#      66     continue
# ---> 68 new_state = State(state)
#      69 new_state.path.append(build)
#      70 if build:
#
# Cell In[3], line 12, in State.__init__(self, prior_state)
#      10 self.depth = prior_state.depth + 1
#      11 self.inventory.update(prior_state.inventory)
# ---> 12 self.robots.update(prior_state.robots)
#      13 self.path.extend(prior_state.path)
#
# KeyboardInterrupt:
