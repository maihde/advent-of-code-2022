# %% [markdown]
# Advent of Code Python Notebook Template
# ========================================

# %%
# iPyTest allows us to solve AoC using test-driven development principals.
import ipytest
ipytest.autoconfig()

# %%
# Modules to support development
import os
import re
import collections
import itertools
import functools
import logging
import pprint
import numpy as np

# %% [markdown]
# Part 1
# ======

# %%
# %%ipytest
#
#
# def part2(puzzle_input):
#     if not os.path.exists(puzzle_input):
#         return
#
#     answer = 0
#
#     with open(puzzle_input) as ff:
#         dd = ff.readlines()
#
#     rope = [ list((0,0)) for _ in range(10) ]
#
#     visited = set()
#
#     # dd is row-wise (dd[0] is the first row)
#     ###############################################################################################################
#     for ll in dd:
#         cmd =  re.match("(\w+) (\d+)", ll)
#         if not cmd:
#             continue
#
#         direction, amount = cmd.groups()
#         amount = int(amount)
#         print(cmd.groups())
#         for nn in range(amount):
#             print("nn", nn, rope[0])
#             if direction == 'U':
#                 rope[0][0] += 1
#             elif direction == 'D':
#                 rope[0][0] -= 1
#             elif direction == 'L':
#                 rope[0][1] -= 1
#             elif direction == 'R':
#                 rope[0][1] += 1
#
#             for ii in range(1, len(rope)):
#
#                 row_delta = (rope[ii-1][0] - rope[ii][0])
#                 col_delta = (rope[ii-1][1] - rope[ii][1])
#
#                 print("  > ", ii, row_delta, col_delta, rope)
#                 assert row_delta in (-2, -1, 0, 1, 2)
#                 assert col_delta in (-2, -1, 0, 1, 2)
#
#                 if row_delta == 2:
#                     rope[ii][0] += 1
#                     rope[ii][1] += col_delta
#                 elif row_delta == -2:
#                     rope[ii][0] -= 1
#                     rope[ii][1] += col_delta
#                 elif row_delta not in (-1, 0, 1):
#                     raise ValueError
#
#                 if col_delta == 2:
#                     rope[ii][0] += row_delta
#                     rope[ii][1] += 1
#                 elif col_delta == -2:
#                     rope[ii][0] += row_delta
#                     rope[ii][1] -= 1
#                 elif col_delta not in (-1, 0, 1):
#                     raise ValueError
#
#                 print("  <  ", ii, row_delta, col_delta, rope)
#
#         print("xx", rope, cmd.groups())
#         visited.add(tuple(rope[-1]))
#
#     answer = len(visited)
#
#     ###############################################################################################################
#
#     return answer
#
# def test_part1():
#     #assert part2(os.path.join("..", "dat", "day9_test.txt")) == 1
#     assert part2(os.path.join("..", "dat", "day9_test2.txt")) == 36
#
#
# #part1(os.path.join("..", "dat", "day9.txt"))

# %%
# %%ipytest
#
#
# def part1(puzzle_input):
#     if not os.path.exists(puzzle_input):
#         return
#
#     answer = 0
#
#     with open(puzzle_input) as ff:
#         dd = ff.readlines()
#
#     rope = [ list((0,0)) for _ in range(2) ]
#
#     visited = set()
#
#     # dd is row-wise (dd[0] is the first row)
#     ###############################################################################################################
#     for ll in dd:
#         cmd =  re.match("(\w+) (\d+)", ll)
#         if not cmd:
#             continue
#
#         direction, amount = cmd.groups()
#         amount = int(amount)
#         for nn in range(amount):
#             if direction == 'U':
#                 rope[0][0] += 1
#             elif direction == 'D':
#                 rope[0][0] -= 1
#             elif direction == 'L':
#                 rope[0][1] -= 1
#             elif direction == 'R':
#                 rope[0][1] += 1
#
#             for ii in range(1, len(rope)):
#
#                 row_delta = (rope[ii-1][0] - rope[ii][0])
#                 col_delta = (rope[ii-1][1] - rope[ii][1])
#
#                 assert row_delta in (-2, -1, 0, 1, 2)
#                 assert col_delta in (-2, -1, 0, 1, 2)
#
#                 if row_delta == 2:
#                     rope[ii][0] += 1
#                     rope[ii][1] += col_delta
#                 elif row_delta == -2:
#                     rope[ii][0] -= 1
#                     rope[ii][1] += col_delta
#                 elif row_delta not in (-1, 0, 1):
#                     raise ValueError
#                 elif col_delta == 2:
#                     rope[ii][0] += row_delta
#                     rope[ii][1] += 1
#                 elif col_delta == -2:
#                     rope[ii][0] += row_delta
#                     rope[ii][1] -= 1
#                 elif col_delta not in (-1, 0, 1):
#                     raise ValueError
#
#             visited.add(tuple(rope[-1]))
#
#     answer = len(visited)
#
#     ###############################################################################################################
#
#     return answer
#
# def test_part1():
#     assert part1(os.path.join("..", "dat", "day9_test.txt")) == 13
#
#
# part1(os.path.join("..", "dat", "day9.txt"))
# Out:
# 5981
# .                                                                                            [100%]
# 1 passed in 0.01s

# %%
# %%ipytest
#
#
# def part2(puzzle_input):
#     if not os.path.exists(puzzle_input):
#         return
#
#     answer = 0
#
#     with open(puzzle_input) as ff:
#         dd = ff.readlines()
#
#     rope = [ list((0,0)) for _ in range(10) ]
#
#     visited = set()
#
#     # dd is row-wise (dd[0] is the first row)
#     ###############################################################################################################
#     for ll in dd:
#         cmd =  re.match("(\w+) (\d+)", ll)
#         if not cmd:
#             continue
#
#         direction, amount = cmd.groups()
#         amount = int(amount)
#         for nn in range(amount):
#             if direction == 'U':
#                 rope[0][0] += 1
#             elif direction == 'D':
#                 rope[0][0] -= 1
#             elif direction == 'L':
#                 rope[0][1] -= 1
#             elif direction == 'R':
#                 rope[0][1] += 1
#
#             for ii in range(1, len(rope)):
#
#                 row_delta = (rope[ii-1][0] - rope[ii][0])
#                 col_delta = (rope[ii-1][1] - rope[ii][1])
#
#                 assert row_delta in (-2, -1, 0, 1, 2)
#                 assert col_delta in (-2, -1, 0, 1, 2)
#
#                 if row_delta == 2 and col_delta == 2:
#                     rope[ii][0] += 1
#                     rope[ii][1] += 1
#                 elif row_delta == 2 and col_delta == -2:
#                     rope[ii][0] += 1
#                     rope[ii][1] -= 1
#                 elif row_delta == -2 and col_delta == -2:
#                     rope[ii][0] -= 1
#                     rope[ii][1] -= 1
#                 elif row_delta == -2 and col_delta == 2:
#                     rope[ii][0] -= 1
#                     rope[ii][1] += 1
#                 elif row_delta == 2:
#                     rope[ii][0] += 1
#                     rope[ii][1] += col_delta
#                 elif row_delta == -2:
#                     rope[ii][0] -= 1
#                     rope[ii][1] += col_delta
#                 elif row_delta not in (-1, 0, 1):
#                     raise ValueError
#                 elif col_delta == 2:
#                     rope[ii][0] += row_delta
#                     rope[ii][1] += 1
#                 elif col_delta == -2:
#                     rope[ii][0] += row_delta
#                     rope[ii][1] -= 1
#                 elif col_delta not in (-1, 0, 1):
#                     raise ValueError
#
#             visited.add(tuple(rope[-1]))
#
#     answer = len(visited)
#
#     ###############################################################################################################
#
#     return answer
#
# def test_part2():
#     assert part2(os.path.join("..", "dat", "day9_test.txt")) == 1
#     assert part2(os.path.join("..", "dat", "day9_test2.txt")) == 36
#
#
# part2(os.path.join("..", "dat", "day9.txt"))
# Out:
# 2352
# .                                                                                            [100%]
# 1 passed in 0.01s
